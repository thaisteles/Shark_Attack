# %% [markdown]
# import pandas as pd

# %%
attack = pd.read_csv('data/attacks.csv', encoding='latin1')
attack.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
# ...

# %%
attack.shape
# Out:
# (25723, 24)

# %%
len(attack)
# Out:
# 25723

# %%
attack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 24 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   Case Number             8702 non-null   object
#  1   Date                    6302 non-null   object
#  2   Year                    6300 non-null   float64
#  3   Type                    6298 non-null   object
#  4   Country                 6252 non-null   object
#  5   Area                    5847 non-null   object
#  6   Location                5762 non-null   object
#  7   Activity                5758 non-null   object
#  8   Name                    6092 non-null   object
#  9   Sex                     5737 non-null   object
#  10  Age                     3471 non-null   object
#  11  Injury                  6274 non-null   object
#  12  Fatal (Y/N)             5763 non-null   object
#  13  Time                    2948 non-null   object
# ...

# %%
attack.describe()
# Out:
#               Year  original order
# count  6300.000000     6309.000000
# mean   1927.272381     3155.999683
# std     281.116308     1821.396206
# min       0.000000        2.000000
# 25%    1942.000000     1579.000000
# 50%    1977.000000     3156.000000
# 75%    2005.000000     4733.000000
# max    2018.000000     6310.000000

# %%
column_order = ['Case Number', 'Date', 'Year', 'Time', 'Country', 'Area', 'Location',
      'Type', 'Activity', 'Name', 'Sex ', 'Age', 'Injury', 'Fatal (Y/N)', 
       'Species ', 'Investigator or Source', 'pdf', 'href formula', 'href',
       'Case Number.1', 'Case Number.2', 'original order', 'Unnamed: 22',
       'Unnamed: 23']

# %%
attack = attack[column_order]
attack.head()
# Out:
#   Case Number         Date    Year           Time    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0          18h00        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  14h00  -15h00        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0          07h45        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0            NaN  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0            NaN     MEXICO           Colima
#
#                          Location        Type     Activity             Name  \
# 0     Oceanside, San Diego County     Boating     Paddling      Julie Wolfe
# 1  St. Simon Island, Glynn County  Unprovoked     Standing  Adyson McNeely
# 2                    Habush, Oahu     Invalid      Surfing      John Denges
# 3              Arrawarra Headland  Unprovoked      Surfing             male
# 4                        La Ticla    Provoked  Free diving   Gustavo Ramos
#
# ...

# %%
attack.columns = [column.lower().replace(' ', '_') for column in attack.columns]

# %%
attack.head()
# Out:
#   case_number         date    year           time    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0          18h00        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  14h00  -15h00        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0          07h45        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0            NaN  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0            NaN     MEXICO           Colima
#
#                          location        type     activity             name  \
# 0     Oceanside, San Diego County     Boating     Paddling      Julie Wolfe
# 1  St. Simon Island, Glynn County  Unprovoked     Standing  Adyson McNeely
# 2                    Habush, Oahu     Invalid      Surfing      John Denges
# 3              Arrawarra Headland  Unprovoked      Surfing             male
# 4                        La Ticla    Provoked  Free diving   Gustavo Ramos
#
# ...

# %%
attack['new_age'] = pd.to_numeric(attack.age, errors='coerce')
attack.head()
# Out:
#   case_number         date    year           time    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0          18h00        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  14h00  -15h00        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0          07h45        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0            NaN  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0            NaN     MEXICO           Colima
#
#                          location        type     activity             name  \
# 0     Oceanside, San Diego County     Boating     Paddling      Julie Wolfe
# 1  St. Simon Island, Glynn County  Unprovoked     Standing  Adyson McNeely
# 2                    Habush, Oahu     Invalid      Surfing      John Denges
# 3              Arrawarra Headland  Unprovoked      Surfing             male
# 4                        La Ticla    Provoked  Free diving   Gustavo Ramos
#
# ...

# %%
attack['new_year'] = pd.to_numeric(attack.year, errors='coerce')
attack.head()
# Out:
#   case_number         date    year           time    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0          18h00        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  14h00  -15h00        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0          07h45        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0            NaN  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0            NaN     MEXICO           Colima
#
#                          location        type     activity             name  \
# 0     Oceanside, San Diego County     Boating     Paddling      Julie Wolfe
# 1  St. Simon Island, Glynn County  Unprovoked     Standing  Adyson McNeely
# 2                    Habush, Oahu     Invalid      Surfing      John Denges
# 3              Arrawarra Headland  Unprovoked      Surfing             male
# 4                        La Ticla    Provoked  Free diving   Gustavo Ramos
#
#    ...                       pdf  \
# ...

# %%
attack.columns
# Out:
# Index(['case_number', 'date', 'year', 'time', 'country', 'area', 'location',
#        'type', 'activity', 'name', 'sex_', 'age', 'injury', 'fatal_(y/n)',
#        'species_', 'investigator_or_source', 'pdf', 'href_formula', 'href',
#        'case_number.1', 'case_number.2', 'original_order', 'unnamed:_22',
#        'unnamed:_23', 'new_age'],
#       dtype='object')

# %%
attack_vars = attack[['case_number', 'date', 'year', 'time', 'country', 'area', 'location',
       'type', 'activity', 'name', 'sex_', 'age', 'injury', 'fatal_(y/n)',
       'species_']]
attack_vars.head()
# Out:
#   case_number         date    year           time    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0          18h00        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  14h00  -15h00        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0          07h45        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0            NaN  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0            NaN     MEXICO           Colima
#
#                          location        type     activity             name  \
# 0     Oceanside, San Diego County     Boating     Paddling      Julie Wolfe
# 1  St. Simon Island, Glynn County  Unprovoked     Standing  Adyson McNeely
# 2                    Habush, Oahu     Invalid      Surfing      John Denges
# 3              Arrawarra Headland  Unprovoked      Surfing             male
# 4                        La Ticla    Provoked  Free diving   Gustavo Ramos
#
# ...

# %%
len(attack.columns)
# Out:
# 25

# %%
len(attack_vars.columns)
# Out:
# 15

# %%
attack_us = attack_vars.query('country == "USA" and type == "Unprovoked"')
attack_us.head()
# Out:
#      case_number         date    year           time country            area  \
# 1     2018.06.18  18-Jun-2018  2018.0  14h00  -15h00     USA         Georgia
# 7     2018.05.27  27-May-2018  2018.0            NaN     USA         Florida
# 8   2018.05.26.b  26-May-2018  2018.0          17h00     USA         Florida
# 9   2018.05.26.a  26-May-2018  2018.0          14h00     USA         Florida
# 11    2018.05.21  21-May-2018  2018.0            NaN     USA  South Carolina
#
#                                              location        type  \
# 1                      St. Simon Island, Glynn County  Unprovoked
# 7   Lighhouse Point Park, Ponce Inlet, Volusia County  Unprovoked
# 8                        Cocoa Beach, Brevard  County  Unprovoked
# 9                       Daytona Beach, Volusia County  Unprovoked
# 11                  Isle of Palms,  Charleston County  Unprovoked
#
#            activity             name sex_ age  \
# 1          Standing  Adyson McNeely     F  11
# ...

# %%
attack_type = attack_vars.query('type == "Unprovoked" and year > 2007 and year <= 2018')
attack_type.head()
# Out:
#     case_number         date    year            time    country  \
# 1    2018.06.18  18-Jun-2018  2018.0   14h00  -15h00        USA
# 3    2018.06.08  08-Jun-2018  2018.0             NaN  AUSTRALIA
# 5  2018.06.03.b  03-Jun-2018  2018.0             NaN  AUSTRALIA
# 6  2018.06.03.a  03-Jun-2018  2018.0  Late afternoon     BRAZIL
# 7    2018.05.27  27-May-2018  2018.0             NaN        USA
#
#               area                                           location  \
# 1          Georgia                     St. Simon Island, Glynn County
# 3  New South Wales                                 Arrawarra Headland
# 5  New South Wales                                 Flat Rock, Ballina
# 6       Pernambuco                              Piedade Beach, Recife
# 7          Florida  Lighhouse Point Park, Ponce Inlet, Volusia County
#
#          type      activity                    name sex_  age  \
# 1  Unprovoked      Standing         Adyson McNeely     F   11
# ...

# %%
Country = attack_type['country']
Country.value_counts()
# Out:
# USA                                      486
# AUSTRALIA                                198
# SOUTH AFRICA                              61
# BAHAMAS                                   33
# REUNION                                   21
# BRAZIL                                    18
# NEW CALEDONIA                             16
# NEW ZEALAND                               15
# EGYPT                                     15
# MEXICO                                    14
# FRENCH POLYNESIA                          12
# SPAIN                                      9
# VIETNAM                                    9
# FIJI                                       8
# ECUADOR                                    6
# MOZAMBIQUE                                 6
# INDONESIA                                  6
# COSTA RICA                                 5
# PHILIPPINES                                4
# JAPAN                                      4
# CUBA                                       3
# ...

# %%
Country = attack_type['country']
Country.value_counts(normalize=True)
# Out:
# USA                                      0.484064
# AUSTRALIA                                0.197211
# SOUTH AFRICA                             0.060757
# BAHAMAS                                  0.032869
# REUNION                                  0.020916
# BRAZIL                                   0.017928
# NEW CALEDONIA                            0.015936
# NEW ZEALAND                              0.014940
# EGYPT                                    0.014940
# MEXICO                                   0.013944
# FRENCH POLYNESIA                         0.011952
# SPAIN                                    0.008964
# VIETNAM                                  0.008964
# FIJI                                     0.007968
# ECUADOR                                  0.005976
# MOZAMBIQUE                               0.005976
# INDONESIA                                0.005976
# COSTA RICA                               0.004980
# PHILIPPINES                              0.003984
# ...

# %%
Activity = attack['activity']
Activity.value_counts()

# %%
Activity = attack['activity']
Activity.value_counts(normalize=True)
# Out:
# Surfing                                                                             0.168635
# Swimming                                                                            0.150920
# Fishing                                                                             0.074852
# Spearfishing                                                                        0.057833
# Bathing                                                                             0.028135
#                                                                                       ...
# Floating on an inflatable raft                                                      0.000174
# Fishingat                                                                           0.000174
# Overcome by CO fumes, fell overboard from 36' fishing cruiser & prop slashed arm    0.000174
# Bathing in 3' to 4' of water                                                        0.000174
# ...

# %%
Age = attack['new_age']
Age.mean()
# Out:
# 27.36835856337192

# %%
attack_type.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Int64Index: 111 entries, 747 to 2073
# Data columns (total 15 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   case_number  111 non-null    object
#  1   date         111 non-null    object
#  2   year         111 non-null    float64
#  3   time         59 non-null     object
#  4   country      111 non-null    object
#  5   area         104 non-null    object
#  6   location     102 non-null    object
#  7   type         111 non-null    object
#  8   activity     110 non-null    object
#  9   name         108 non-null    object
#  10  sex_         106 non-null    object
#  11  age          69 non-null     object
#  12  injury       111 non-null    object
#  13  fatal_(y/n)  110 non-null    object
#  14  species_     88 non-null     object
# dtypes: float64(1), object(14)
# memory usage: 13.9+ KB

# %%
attack.species_
# Out:
# 0            White shark
# 1                    NaN
# 2                    NaN
# 3              2 m shark
# 4        Tiger shark, 3m
#               ...
# 25718                NaN
# 25719                NaN
# 25720                NaN
# 25721                NaN
# 25722                NaN
# Name: species_, Length: 25723, dtype: object

# %%
Species = attack['species_']
Species.value_counts()
# Out:
# White shark                                                                                   163
# Shark involvement prior to death was not confirmed                                            105
# Invalid                                                                                       102
# Shark involvement not confirmed                                                                88
# Tiger shark                                                                                    73
#                                                                                              ...
# 36"  shark                                                                                      1
# 7-gill shark?                                                                                   1
# On 11-Jan-1994, his remains washed ashore. A 2.4 m [8'] tiger shark thought to be involved      1
# White shark, 2m to 3 m                                                                          1
# ...

# %%
attack_species = attack_vars.query('type == "Unprovoked" and species_ == "White shark"')
attack_species.head()
# Out:
#       case_number         date    year   time       country  \
# 34     2018.04.03  03-Apr-2018  2018.0  15h00  SOUTH AFRICA
# 155  2017.04.17.a  17-Apr-2017  2017.0  16h00     AUSTRALIA
# 197    2016.12.01  01-Dec-2016  2016.0  09h00     AUSTRALIA
# 258    2016.06.23  23-Jun-2016  2016.0    NaN  SOUTH AFRICA
# 271    2016.05.31  31-May-2016  2016.0  16h00     AUSTRALIA
#
#                       area                   location        type  \
# 34   Eastern Cape Province            St. Francis Bay  Unprovoked
# 155      Western Australia     Kelpies near Wylie Bay  Unprovoked
# 197        New South Wales  Booti Booti National Park  Unprovoked
# 258  Western Cape Province                    Ryspunt  Unprovoked
# 271      Western Australia     Falcon Beach, Mandurah  Unprovoked
#
#          activity              name sex_ age  \
# 34        Surfing      Ross Spowart    M  19
# 155       Surfing  Laeticia Brouwer    F  17
# 197       Surfing     Colin Rowland    M  65
# ...

# %%
Type = attack['type']
Type
# Out:
# 0           Boating
# 1        Unprovoked
# 2           Invalid
# 3        Unprovoked
# 4          Provoked
#             ...
# 25718           NaN
# 25719           NaN
# 25720           NaN
# 25721           NaN
# 25722           NaN
# Name: type, Length: 25723, dtype: object

# %%
Type.value_counts()
# Out:
# Unprovoked      4595
# Provoked         574
# Invalid          547
# Sea Disaster     239
# Boating          203
# Boat             137
# Questionable       2
# Boatomg            1
# Name: type, dtype: int64

# %%
Type.value_counts(normalize=True)
# Out:
# Unprovoked      0.729597
# Provoked        0.091140
# Invalid         0.086853
# Sea Disaster    0.037949
# Boating         0.032232
# Boat            0.021753
# Questionable    0.000318
# Boatomg         0.000159
# Name: type, dtype: float64

# %%
Type.sort_values(ascending=False)
# Out:
# 6301     Unprovoked
# 2331     Unprovoked
# 2321     Unprovoked
# 2322     Unprovoked
# 2323     Unprovoked
#             ...
# 25718           NaN
# 25719           NaN
# 25720           NaN
# 25721           NaN
# 25722           NaN
# Name: type, Length: 25723, dtype: object

# %%
Country  = attack_vars['country']
Country.value_counts()
# Out:
# USA                  2229
# AUSTRALIA            1338
# SOUTH AFRICA          579
# PAPUA NEW GUINEA      134
# NEW ZEALAND           128
#                      ...
# TASMAN SEA              1
# ITALY / CROATIA         1
# RED SEA                 1
# ADMIRALTY ISLANDS       1
# ANDAMAN ISLANDS         1
# Name: country, Length: 212, dtype: int64

# %%
Location = attack['location']
Location
# Out:
# 0           Oceanside, San Diego County
# 1        St. Simon Island, Glynn County
# 2                          Habush, Oahu
# 3                    Arrawarra Headland
# 4                              La Ticla
#                       ...
# 25718                               NaN
# 25719                               NaN
# 25720                               NaN
# 25721                               NaN
# 25722                               NaN
# Name: location, Length: 25723, dtype: object

# %%
Location.value_counts()
# Out:
# New Smyrna Beach, Volusia County                           163
# Daytona Beach, Volusia County                               30
# Ponce Inlet, Volusia County                                 20
# Melbourne Beach, Brevard County                             18
# Myrtle Beach, Horry County                                  17
#                                                           ...
# Portsea Beach, near entrance to Port Phillip Bay             1
# Charlie Young Beach, Kihei, Maui                             1
# Abalone Point, Westport Union Landing, Mendocino County      1
# Kalapiai, Kombe                                              1
# Fernano de Noronha                                           1
# Name: location, Length: 4108, dtype: int64

# %%
attack[attack.location=='New Smyrna Beach, Volusia County']
# Out:
#        case_number         date    year            time country     area  \
# 95    2017.09.02.a  02-Sep-2017  2017.0           10h44     USA  Florida
# 164     2017.04.05  05-Apr-2017  2017.0           13h00     USA  Florida
# 167     2017.03.27  27-Mar-2017  2017.0           10h00     USA  Florida
# 195   2016.12.11.a  11-Dec-2016  2016.0       Afternoon     USA  Florida
# 209     2016.10.02  02-Oct-2016  2016.0           11h30     USA  Florida
# ...            ...          ...     ...             ...     ...      ...
# 3265    1974.06.20  20-Jun-1974  1974.0           08h55     USA  Florida
# 3322  1972.10.14.a  14-Oct-1972  1972.0             NaN     USA  Florida
# 3423    1969.08.02  02-Aug-1969  1969.0         Morning     USA  Florida
# 3744    1963.07.15  15-Jul-1963  1963.0  Late afternoon     USA  Florida
# 3813    1962.06.17  17-Jun-1962  1962.0           11h50     USA  Florida
#
#                               location        type         activity  \
# ...

# %%
attack[attack.location=='New Smyrna Beach, Volusia County'].groupby('type').size()
# Out:
# type
# Invalid         3
# Provoked        3
# Unprovoked    157
# dtype: int64

# %%
attack[attack.country=='USA'].groupby('type').size()
attack.head()
# Out:
#   case_number         date    year           time    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0          18h00        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  14h00  -15h00        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0          07h45        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0            NaN  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0            NaN     MEXICO           Colima
#
#                          location        type     activity             name  \
# 0     Oceanside, San Diego County     Boating     Paddling      Julie Wolfe
# 1  St. Simon Island, Glynn County  Unprovoked     Standing  Adyson McNeely
# 2                    Habush, Oahu     Invalid      Surfing      John Denges
# 3              Arrawarra Headland  Unprovoked      Surfing             male
# 4                        La Ticla    Provoked  Free diving   Gustavo Ramos
#
#    ...                       pdf  \
# ...

# %%
attack[attack.country=='USA'].groupby('species_').size()
attack.head()
# Out:
#   case_number         date    year           time    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0          18h00        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  14h00  -15h00        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0          07h45        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0            NaN  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0            NaN     MEXICO           Colima
#
#                          location        type     activity             name  \
# 0     Oceanside, San Diego County     Boating     Paddling      Julie Wolfe
# 1  St. Simon Island, Glynn County  Unprovoked     Standing  Adyson McNeely
# 2                    Habush, Oahu     Invalid      Surfing      John Denges
# 3              Arrawarra Headland  Unprovoked      Surfing             male
# 4                        La Ticla    Provoked  Free diving   Gustavo Ramos
#
#    ...                       pdf  \
# ...

# %%
attack[attack.type=='Unprovoked'].groupby('species_').size()
attack.head()
# Out:
#   case_number         date    year           time    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0          18h00        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  14h00  -15h00        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0          07h45        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0            NaN  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0            NaN     MEXICO           Colima
#
#                          location        type     activity             name  \
# 0     Oceanside, San Diego County     Boating     Paddling      Julie Wolfe
# 1  St. Simon Island, Glynn County  Unprovoked     Standing  Adyson McNeely
# 2                    Habush, Oahu     Invalid      Surfing      John Denges
# 3              Arrawarra Headland  Unprovoked      Surfing             male
# 4                        La Ticla    Provoked  Free diving   Gustavo Ramos
#
#    ...                       pdf  \
# ...

# %%
Location.value_counts(normalize=True)
# Out:
# New Smyrna Beach, Volusia County                           0.028289
# Daytona Beach, Volusia County                              0.005207
# Ponce Inlet, Volusia County                                0.003471
# Melbourne Beach, Brevard County                            0.003124
# Myrtle Beach, Horry County                                 0.002950
#                                                              ...
# Portsea Beach, near entrance to Port Phillip Bay           0.000174
# Charlie Young Beach, Kihei, Maui                           0.000174
# Abalone Point, Westport Union Landing, Mendocino County    0.000174
# Kalapiai, Kombe                                            0.000174
# Fernano de Noronha                                         0.000174
# Name: location, Length: 4108, dtype: float64

# %%
# Qual a idade média das vítimas de ataques
#limpar coluna idade

attack.Age
# Out:
# 0         57
# 1         11
# 2         48
# 3        NaN
# 4        NaN
#         ...
# 25718    NaN
# 25719    NaN
# 25720    NaN
# 25721    NaN
# 25722    NaN
# Name: Age, Length: 25723, dtype: object

# %%
pd.to_numeric(attack.Age, errors='coerce')
# Out:
# 0        57.0
# 1        11.0
# 2        48.0
# 3         NaN
# 4         NaN
#          ...
# 25718     NaN
# 25719     NaN
# 25720     NaN
# 25721     NaN
# 25722     NaN
# Name: Age, Length: 25723, dtype: float64

# %%
attack['new_age'] = pd.to_numeric(attack.Age, errors='coerce')

# %%
attack.head()
# Out:
#   Case Number         Date    Year        Type    Country             Area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          Location     Activity             Name Sex   ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#            Investigator or Source                       pdf  \
# ...

# %%
attack.describe()
# Out:
#               Year  original order      new_age
# count  6300.000000     6309.000000  3369.000000
# mean   1927.272381     3155.999683    27.368359
# std     281.116308     1821.396206    13.907779
# min       0.000000        2.000000     1.000000
# 25%    1942.000000     1579.000000    17.000000
# 50%    1977.000000     3156.000000    24.000000
# 75%    2005.000000     4733.000000    35.000000
# max    2018.000000     6310.000000    87.000000

# %%
attack['new_date'] = pd.to_numeric(attack.date, errors='coerce')
attack.head()
# Out:
#   case_number         date    year        type    country             area  \
# 0  2018.06.25  25-Jun-2018  2018.0     Boating        USA       California
# 1  2018.06.18  18-Jun-2018  2018.0  Unprovoked        USA          Georgia
# 2  2018.06.09  09-Jun-2018  2018.0     Invalid        USA           Hawaii
# 3  2018.06.08  08-Jun-2018  2018.0  Unprovoked  AUSTRALIA  New South Wales
# 4  2018.06.04  04-Jun-2018  2018.0    Provoked     MEXICO           Colima
#
#                          location     activity             name sex_  ...  \
# 0     Oceanside, San Diego County     Paddling      Julie Wolfe    F  ...
# 1  St. Simon Island, Glynn County     Standing  Adyson McNeely     F  ...
# 2                    Habush, Oahu      Surfing      John Denges    M  ...
# 3              Arrawarra Headland      Surfing             male    M  ...
# 4                        La Ticla  Free diving   Gustavo Ramos     M  ...
#
#                         pdf  \
# 0      2018.06.25-Wolfe.pdf
# ...

# %%
attack.describe()
# Out:
#               year  original_order      new_age      new_date
# count  6300.000000     6309.000000  3369.000000    287.000000
# mean   1927.272381     3155.999683    27.368359   2058.623693
# std     281.116308     1821.396206    13.907779   1580.758729
# min       0.000000        2.000000     1.000000   1555.000000
# 25%    1942.000000     1579.000000    17.000000   1904.000000
# 50%    1977.000000     3156.000000    24.000000   1944.000000
# 75%    2005.000000     4733.000000    35.000000   1959.000000
# max    2018.000000     6310.000000    87.000000  21764.000000

# %%
attack.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 25723 entries, 0 to 25722
# Data columns (total 26 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   case_number             8702 non-null   object
#  1   date                    6302 non-null   object
#  2   year                    6300 non-null   float64
#  3   type                    6298 non-null   object
#  4   country                 6252 non-null   object
#  5   area                    5847 non-null   object
#  6   location                5762 non-null   object
#  7   activity                5758 non-null   object
#  8   name                    6092 non-null   object
#  9   sex_                    5737 non-null   object
#  10  age                     3471 non-null   object
#  11  injury                  6274 non-null   object
#  12  fatal_(y/n)             5763 non-null   object
#  13  time                    2948 non-null   object
# ...

# %%
attack_date = attack.query('type == "Provoked"' and 'year > 2012 and year <= 2018')
attack_date
# Out:
#       case_number                  date    year        type      country  \
# 0      2018.06.25           25-Jun-2018  2018.0     Boating          USA
# 1      2018.06.18           18-Jun-2018  2018.0  Unprovoked          USA
# 2      2018.06.09           09-Jun-2018  2018.0     Invalid          USA
# 3      2018.06.08           08-Jun-2018  2018.0  Unprovoked    AUSTRALIA
# 4      2018.06.04           04-Jun-2018  2018.0    Provoked       MEXICO
# ..            ...                   ...     ...         ...          ...
# 707    2013.01.25           25-Jan-2013  2013.0  Unprovoked    AUSTRALIA
# 708  2013.01.21.R  Reported 21-Jan-2013  2013.0     Invalid    AUSTRALIA
# 709    2013.01.16           16-Jan-2013  2013.0  Unprovoked          USA
# 710    2013.01.13           13-Jan-2013  2013.0  Unprovoked  NEW ZEALAND
# 711    2013.01.05           05-Jan-2013  2013.0  Unprovoked    AUSTRALIA
#
#                   area                        location  \
# ...

# %%
#Onde teve ataque provocado
attack.groupby(['Location', 'Type']).size().sort_values(ascending=False)
# Out:
# Location                                        Type
# New Smyrna Beach, Volusia County                Unprovoked    157
# Daytona Beach, Volusia County                   Unprovoked     30
# Ponce Inlet, Volusia County                     Unprovoked     18
# Melbourne Beach, Brevard County                 Unprovoked     17
# Myrtle Beach, Horry County                      Unprovoked     15
#                                                              ...
# Off Palos Verdes peninsula, Los Angeles County  Boating         1
# Off Palos Verdes Estates, Los Angeles           Boat            1
# Off Ocean City, Cape May County                 Provoked        1
# Off North Island                                Invalid         1
#                                                 Unprovoked      1
# Length: 4424, dtype: int64

# %%
attack.groupby(['Location', 'Type']).size().sort_values(ascending=False).unstack()
# Out:
# Type                                            Boat  Boating  Boatomg  \
# Location
# New Smyrna Beach, Volusia County                 NaN      NaN      NaN
# Daytona Beach, Volusia County                    NaN      NaN      NaN
# Ponce Inlet, Volusia County                      NaN      NaN      NaN
# Melbourne Beach, Brevard County                  NaN      NaN      NaN
# Myrtle Beach, Horry County                       NaN      NaN      NaN
# ...                                              ...      ...      ...
# Off Palos Verdes peninsula, Los Angeles County   NaN      1.0      NaN
# Off Palos Verdes Estates, Los Angeles            1.0      NaN      NaN
# Off Ocean City, Cape May County                  NaN      NaN      NaN
# Off North Island                                 NaN      NaN      NaN
#                                                  NaN      NaN      NaN
#
# Type                                            Invalid  Provoked  \
# Location
# ...
